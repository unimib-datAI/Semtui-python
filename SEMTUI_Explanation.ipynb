# %% [markdown]
# ## **CSV file input**

# %% [markdown]
# | Fecha_id | Keyword                | Impresiones | Clicks | City       | County           | Country        |
# |----------|------------------------|-------------|--------|------------|------------------|----------------|
# | 20230101 | alquiler pisos colindres| 1           | 0      | Madrid     | Community of Madrid | Spain          |
# | 20230101 | alquiler pisos sestao  | 1           | 0      | Barcelona  | Catalonia        | Spain          |
# | 20230101 | steelcraft pedal car   | 1           | 0      | Buffalo    | New York         | United States |

# %% [markdown]
# ## **JSON File From Backend**

# %% [markdown]
# **Table Metadata**
# - **id**: `141`
# - **idDataset**: `30`
# - **name**: `JOT_tiny_1`
# - **nCols**: `7`
# - **nRows**: `3`
# - **nCells**: `21`
# - **nCellsReconciliated**: `0`
# - **lastModifiedDate**: `2024-06-10T15:48:49.233Z`
#
# **Columns Metadata**
# - **Fecha_id**:
#   - **id**: `Fecha_id`
#   - **label**: `Fecha_id`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
# - **Keyword**:
#   - **id**: `Keyword`
#   - **label**: `Keyword`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
# - **Impresiones**:
#   - **id**: `Impresiones`
#   - **label**: `Impresiones`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
# - **Clicks**:
#   - **id**: `Clicks`
#   - **label**: `Clicks`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
# - **City**:
#   - **id**: `City`
#   - **label**: `City`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
# - **County**:
#   - **id**: `County`
#   - **label**: `County`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
# - **Country**:
#   - **id**: `Country`
#   - **label**: `Country`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
#
# **Rows Data**
#
# - **r0**:
#   - **Fecha_id**:
#     - **id**: `r0$Fecha_id`
#     - **label**: `2023-01-01`
#     - **metadata**: `[]`
#   - **Keyword**:
#     - **id**: `r0$Keyword`
#     - **label**: `alquiler pisos colindres`
#     - **metadata**: `[]`
#   - **Impresiones**:
#     - **id**: `r0$Impresiones`
#     - **label**: `1`
#     - **metadata**: `[]`
#   - **Clicks**:
#     - **id**: `r0$Clicks`
#     - **label**: `0`
#     - **metadata**: `[]`
#   - **City**:
#     - **id**: `r0$City`
#     - **label**: `Madrid`
#     - **metadata**: `[]`
#   - **County**:
#     - **id**: `r0$County`
#     - **label**: `Community of Madrid`
#     - **metadata**: `[]`
#   - **Country**:
#     - **id**: `r0$Country`
#     - **label**: `Spain`
#     - **metadata**: `[]`
#
# - **r1**:
#   - **Fecha_id**:
#     - **id**: `r1$Fecha_id`
#     - **label**: `2023-01-01`
#     - **metadata**: `[]`
#   - **Keyword**:
#     - **id**: `r1$Keyword`
#     - **label**: `alquiler pisos sestao`
#     - **metadata**: `[]`
#   - **Impresiones**:
#     - **id**: `r1$Impresiones`
#     - **label**: `1`
#     - **metadata**: `[]`
#   - **Clicks**:
#     - **id**: `r1$Clicks`
#     - **label**: `0`
#     - **metadata**: `[]`
#   - **City**:
#     - **id**: `r1$City`
#     - **label**: `Barcelona`
#     - **metadata**: `[]`
#   - **County**:
#     - **id**: `r1$County`
#     - **label**: `Catalonia`
#     - **metadata**: `[]`
#   - **Country**:
#     - **id**: `r1$Country`
#     - **label**: `Spain`
#     - **metadata**: `[]`
#
# - **r2**:
#   - **Fecha_id**:
#     - **id**: `r2$Fecha_id`
#     - **label**: `2023-01-01`
#     - **metadata**: `[]`
#   - **Keyword**:
#     - **id**: `r2$Keyword`
#     - **label**: `steelcraft pedal car`
#     - **metadata**: `[]`
#   - **Impresiones**:
#     - **id**: `r2$Impresiones`
#     - **label**: `1`
#     - **metadata**: `[]`
#   - **Clicks**:
#     - **id**: `r2$Clicks`
#     - **label**: `0`
#     - **metadata**: `[]`
#   - **City**:
#     - **id**: `r2$City`
#     - **label**: `Buffalo`
#     - **metadata**: `[]`
#   - **County**:
#     - **id**: `r2$County`
#     - **label**: `New York`
#     - **metadata**: `[]`
#   - **Country**:
#     - **id**: `r2$Country`
#     - **label**: `United States`
#     - **metadata**: `[]`

# %% [markdown]
# ### Column Example
#
# Let's use the **City** column as an example.
#
# **Input CSV Column:**
# ```markdown
# | City       |
# |------------|
# | Madrid     |
# | Barcelona  |
# | Buffalo    |
# ```
#
# **Backend Enhanced Column:**
# - **City**:
#   - **id**: `City`
#   - **label**: `City`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
#
# **Explanation:**
# 1. **id**: The unique identifier for the column (e.g., `City`).
# 2. **label**: The name of the column (e.g., `City`).
# 3. **status**: The status of the column (e.g., `empty`). Indicates whether the column has been processed or not.
# 4. **context**: Additional context information for the column (empty in this case, represented as `{}`).
# 5. **metadata**: An array that can hold metadata objects related to the column (empty in this case, represented as `[]`).
#
# ### Row Example
# Let's use the first row (**r0**) as an example.
#
# **Input CSV Row:**
#
# | 20230101 | alquiler pisos colindres | 1 | 0 | Madrid | Community of Madrid | Spain |
#
# **Backend Enhanced Row:**
#
# - **r0**:
#   - **Fecha_id**:
#     - **id**: `r0$Fecha_id`
#     - **label**: `2023-01-01`
#     - **metadata**: `[]`
#   - **Keyword**:
#     - **id**: `r0$Keyword`
#     - **label**: `alquiler pisos colindres`
#     - **metadata**: `[]`
#   - **Impresiones**:
#     - **id**: `r0$Impresiones`
#     - **label**: `1`
#     - **metadata**: `[]`
#   - **Clicks**:
#     - **id**: `r0$Clicks`
#     - **label**: `0`
#     - **metadata**: `[]`
#   - **City**:
#     - **id**: `r0$City`
#     - **label**: `Madrid`
#     - **metadata**: `[]`
#   - **County**:
#     - **id**: `r0$County`
#     - **label**: `Community of Madrid`
#     - **metadata**: `[]`
#   - **Country**:
#     - **id**: `r0$Country`
#     - **label**: `Spain`
#     - **metadata**: `[]`
#
# **Explanation:**
# 1. **Row ID**:
#     - **id**: Unique identifier for the row (e.g., `r0`).
# 2. **Cells**:
#    - For each cell in the row:
#      - **id**: Unique identifier for the cell, combining row and column IDs (e.g., `r0$Fecha_id` for the `Fecha_id` column in the first row).
#      - **label**: The actual value of the cell (e.g., `2023-01-01` for the `Fecha_id` column in the first row).
#      - **metadata**: An array that can hold metadata objects related to the cell (empty in this case, represented as `[]`).
#
# ### Summary
# **For Columns:**
# - Additional fields:
#   - **id**: Unique identifier for the column.
#   - **label**: The name of the column.
#   - **status**: Indicates whether the column has been processed or not (e.g., `empty`).
#   - **context**: Additional context information for the column (e.g., `{}`).
#   - **metadata**: An array that can hold metadata objects related to the column (e.g., `[]`).
#
# **For Rows:**
# - Additional fields:
#   - **id**: Unique identifier for the row.
#   - **cells**: Each cell in the row contains:
#     - **id**: Unique identifier for the cell, combining row and column IDs.
#     - **label**: The actual value of the cell.
#     - **metadata**: An array that can hold metadata objects related to the cell.
#
# The backend takes the original CSV data and adds these additional fields to provide more structured and enriched information, which can be used for further processing, reconciliation, and analysis.

# %% [markdown]
# ## **JSON File From Reconciliation**

# %% [markdown]
# ### Table Metadata
#
# **Table Metadata**
# - **id**: `140`
# - **idDataset**: `30`
# - **name**: `JoT-Semtui-reconciled`
# - **nCols**: `7`
# - **nRows**: `3`
# - **nCells**: `21`
# - **nCellsReconciliated**: `3`
# - **lastModifiedDate**: `2024-06-06T11:01:56.136Z`
# - **minMetaScore**: `0`
# - **maxMetaScore**: `1`
#
# ### Columns Metadata
#
# **Columns Metadata**
# - **Fecha_id**:
#   - **id**: `Fecha_id`
#   - **label**: `Fecha_id`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
# - **Keyword**:
#   - **id**: `Keyword`
#   - **label**: `Keyword`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
# - **Impresiones**:
#   - **id**: `Impresiones`
#   - **label**: `Impresiones`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
# - **Clicks**:
#   - **id**: `Clicks`
#   - **label**: `Clicks`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
# - **City**:
#   - **id**: `City`
#   - **label**: `City`
#   - **status**: `reconciliated`
#   - **context**:
#     - **georss**:
#       - **uri**: `http://www.google.com/maps/place/`
#       - **total**: `3`
#       - **reconciliated**: `3`
#   - **metadata**:
#     - **id**: `None:`
#       - **match**: `true`
#       - **score**: `0`
#       - **name**:
#         - **value**: ``
#         - **uri**: ``
#       - **entity**:
#         - **id**: `wd:Q29934236`
#           - **name**:
#             - **value**: `GlobeCoordinate`
#             - **uri**: `http://149.132.176.67:3002/map?polyline=Q29934236`
#           - **score**: `0`
#           - **match**: `true`
#           - **type**: `[]`
#         - **id**: `georss:point`
#           - **name**:
#             - **value**: `point`
#             - **uri**: `http://149.132.176.67:3002/map?polyline=point`
#           - **score**: `0`
#           - **match**: `true`
#           - **type**: `[]`
#   - **annotationMeta**:
#     - **annotated**: `true`
#     - **match**:
#       - **value**: `true`
#       - **reason**: `reconciliator`
#     - **lowestScore**: `0`
#     - **highestScore**: `0`
# - **County**:
#   - **id**: `County`
#   - **label**: `County`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
# - **Country**:
#   - **id**: `Country`
#   - **label**: `Country`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
#
# ### Rows Data
#
# **Rows Data**
#
# - **r0**:
#   - **Fecha_id**:
#     - **id**: `r0$Fecha_id`
#     - **label**: `2023-01-01`
#     - **metadata**: `[]`
#   - **Keyword**:
#     - **id**: `r0$Keyword`
#     - **label**: `alquiler pisos colindres`
#     - **metadata**: `[]`
#   - **Impresiones**:
#     - **id**: `r0$Impresiones`
#     - **label**: `1`
#     - **metadata**: `[]`
#   - **Clicks**:
#     - **id**: `r0$Clicks`
#     - **label**: `0`
#     - **metadata**: `[]`
#   - **City**:
#     - **id**: `r0$City`
#     - **label**: `Madrid`
#     - **metadata**:
#       - **id**: `georss:40.41955,-3.69196`
#         - **name**:
#           - **value**: `Madrid, Community of Madrid, Spain`
#           - **uri**: `http://149.132.176.67:3002/map?polyline=40.41955,-3.69196`
#         - **feature**:
#           - **id**: `all_labels`
#           - **value**: `100`
#         - **score**: `1`
#         - **match**: `true`
#         - **type**:
#           - **id**: `wd:Q29934236`
#             - **name**: `GlobeCoordinate`
#           - **id**: `georss:point`
#             - **name**: `point`
#     - **annotationMeta**:
#       - **annotated**: `true`
#       - **match**:
#         - **value**: `true`
#         - **reason**: `reconciliator`
#       - **lowestScore**: `1`
#       - **highestScore**: `1`
#   - **County**:
#     - **id**: `r0$County`
#     - **label**: `Community of Madrid`
#     - **metadata**: `[]`
#   - **Country**:
#     - **id**: `r0$Country`
#     - **label**: `Spain`
#     - **metadata**: `[]`
#
# - **r1**:
#   - **Fecha_id**:
#     - **id**: `r1$Fecha_id`
#     - **label**: `2023-01-01`
#     - **metadata**: `[]`
#   - **Keyword**:
#     - **id**: `r1$Keyword`
#     - **label**: `alquiler pisos sestao`
#     - **metadata**: `[]`
#   - **Impresiones**:
#     - **id**: `r1$Impresiones`
#     - **label**: `1`
#     - **metadata**: `[]`
#   - **Clicks**:
#     - **id**: `r1$Clicks

# %% [markdown]
# #### Summary of the fields in the Root Object, Columns Object, and Rows Object:
#
# ### Root Object
# - **table**: Metadata about the entire dataset.
#   - **id**: Unique identifier for the table.
#   - **idDataset**: Identifier for the dataset to which this table belongs.
#   - **name**: Name of the table.
#   - **nCols**: Number of columns in the table.
#   - **nRows**: Number of rows in the table.
#   - **nCells**: Total number of cells in the table.
#   - **nCellsReconciliated**: Number of cells that have been reconciliated.
#   - **lastModifiedDate**: Date and time when the table was last modified.
#   - **minMetaScore**: Minimum metadata score.
#   - **maxMetaScore**: Maximum metadata score.
#
# ### Columns Object
# - **columns**: Metadata for each column in the table.
#   - **id**: Unique identifier for the column.
#   - **label**: Label or name of the column.
#   - **status**: Current status of the column (e.g., "empty", "reconciliated").
#   - **context**: Additional context information.
#     - **georss**: (For "City" column) Geographic RSS data.
#       - **uri**: Base URI for the geographic data.
#       - **total**: Total number of reconciliated entries.
#       - **reconciliated**: Number of entries reconciliated.
#   - **metadata**: Array of metadata objects for the column.
#     - **id**: Identifier for the metadata entry.
#     - **match**: Boolean indicating if there is a match.
#     - **score**: Score for the match.
#     - **name**: Object with value and URI fields.
#       - **value**: Name value.
#       - **uri**: URI associated with the name.
#     - **entity**: Array of entity objects.
#       - **id**: Identifier for the entity.
#       - **name**: Object containing the entity name and URI.
#         - **value**: Entity name.
#         - **uri**: URI for the entity.
#       - **score**: Score for the entity.
#       - **match**: Boolean indicating if there is a match.
#       - **type**: Array of types.
#     - **annotationMeta**: Metadata about the annotation.
#       - **annotated**: Boolean indicating if the column is annotated.
#       - **match**: Object containing match information.
#         - **value**: Boolean indicating if there is a match.
#         - **reason**: Reason for the match.
#       - **lowestScore**: Lowest score for the annotation.
#       - **highestScore**: Highest score for the annotation.
#
# ### Rows Object
# - **rows**: Data for each row in the table.
#   - **id**: Unique identifier for the row.
#   - **cells**: Object containing data for each cell in the row.
#     - **id**: Unique identifier for the cell.
#     - **label**: Data value of the cell.
#     - **metadata**: Array of metadata objects for the cell.
#       - **id**: Identifier for the metadata entry.
#       - **name**: Object with value and URI fields.
#         - **value**: Name value.
#         - **uri**: URI associated with the name.
#       - **feature**: Array of feature objects.
#         - **id**: Identifier for the feature.
#         - **value**: Value of the feature.
#       - **score**: Score for the match.
#       - **match**: Boolean indicating if there is a match.
#       - **type**: Array of types.
#         - **id**: Identifier for the type.
#         - **name**: Name of the type.
#       - **annotationMeta**: Metadata about the annotation (same structure as in the columns object).

# %% [markdown]
# Below is a detailed explanation of the JSON structure and the data it contains for your semantic enrichment process.
#
# ### JSON Structure and Fields
#
# #### Root Object
# - **table**: This object contains metadata about the entire dataset.
#   - **id**: The unique identifier for this table (e.g., "140").
#   - **idDataset**: The identifier for the dataset to which this table belongs (e.g., "30").
#   - **name**: The name of the table (e.g., "JoT-Semtui-reconciled").
#   - **nCols**: The number of columns in the table (e.g., 7).
#   - **nRows**: The number of rows in the table (e.g., 3).
#   - **nCells**: The total number of cells in the table (e.g., 21).
#   - **nCellsReconciliated**: The number of cells that have been reconciliated (e.g., 3).
#   - **lastModifiedDate**: The date and time when the table was last modified (e.g., "2024-06-06T11:01:56.136Z").
#   - **minMetaScore**: The minimum metadata score (e.g., 0).
#   - **maxMetaScore**: The maximum metadata score (e.g., 1).
#
# #### Columns Object
# - **columns**: This object contains metadata for each column in the table.
#   - Each column is represented by a key (e.g., "Fecha_id", "Keyword", etc.) with a nested object containing:
#     - **id**: The unique identifier for the column (e.g., "Fecha_id").
#     - **label**: The label or name of the column (e.g., "Fecha_id").
#     - **status**: The current status of the column (e.g., "empty", "reconciliated").
#     - **context**: Additional context information (often empty except for the "City" column, which contains georss metadata).
#       - **georss**: Geographic RSS (Really Simple Syndication) data for the "City" column.
#         - **uri**: Base URI for the geographic data (e.g., "http://www.google.com/maps/place/").
#         - **total**: Total number of reconciliated entries (e.g., 3).
#         - **reconciliated**: Number of entries reconciliated (e.g., 3).
#     - **metadata**: An array containing metadata objects for the column (empty for most, but contains detailed information for "City").
#       - **id**: Identifier for the metadata entry (e.g., "None:").
#       - **match**: Boolean indicating if there is a match (e.g., true).
#       - **score**: The score for the match (e.g., 0).
#       - **name**: An object with value and URI fields.
#         - **value**: The name value (e.g., "GlobeCoordinate").
#         - **uri**: The URI associated with the name (e.g., "http://149.132.176.67:3002/map?polyline=Q29934236").
#       - **entity**: An array of entity objects.
#         - **id**: Identifier for the entity (e.g., "wd:Q29934236").
#         - **name**: Object containing the entity name and URI.
#           - **value**: The entity name (e.g., "GlobeCoordinate").
#           - **uri**: The URI for the entity (e.g., "http://149.132.176.67:3002/map?polyline=Q29934236").
#         - **score**: The score for the entity (e.g., 0).
#         - **match**: Boolean indicating if there is a match (e.g., true).
#         - **type**: Array of types (empty in this example).
#     - **annotationMeta**: Metadata about the annotation.
#       - **annotated**: Boolean indicating if the column is annotated (e.g., true).
#       - **match**: Object containing match information.
#         - **value**: Boolean indicating if there is a match (e.g., true).
#         - **reason**: The reason for the match (e.g., "reconciliator").
#       - **lowestScore**: The lowest score for the annotation (e.g., 0).
#       - **highestScore**: The highest score for the annotation (e.g., 0).
#
# #### Rows Object
# - **rows**: This object contains data for each row in the table.
#   - Each row is represented by a key (e.g., "r0", "r1", "r2") with a nested object containing:
#     - **id**: The unique identifier for the row (e.g., "r0").
#     - **cells**: An object containing data for each cell in the row.
#       - Each cell is represented by a key (e.g., "Fecha_id", "Keyword", etc.) with a nested object containing:
#         - **id**: The unique identifier for the cell (e.g., "r0$Fecha_id").
#         - **label**: The data value of the cell (e.g., "2023-01-01").
#         - **metadata**: An array containing metadata objects for the cell (empty in most cases but contains detailed information for "City").
#           - **id**: Identifier for the metadata entry (e.g., "georss:40.41955,-3.69196").
#           - **name**: An object with value and URI fields.
#             - **value**: The name value (e.g., "Madrid, Community of Madrid, Spain").
#             - **uri**: The URI associated with the name (e.g., "http://149.132.176.67:3002/map?polyline=40.41955,-3.69196").
#           - **feature**: An array of feature objects.
#             - **id**: Identifier for the feature (e.g., "all_labels").
#             - **value**: The value of the feature (e.g., 100).
#           - **score**: The score for the match (e.g., 1).
#           - **match**: Boolean indicating if there is a match (e.g., true).
#           - **type**: Array of types.
#             - **id**: Identifier for the type (e.g., "wd:Q29934236").
#             - **name**: The name of the type (e.g., "GlobeCoordinate").
#         - **annotationMeta**: Metadata about the annotation (same structure as in the columns object).
#
# ### Summary
# - The JSON structure contains metadata about the dataset, columns, and rows.
# - The `columns` object provides detailed information about each column, including its reconciliation status and associated metadata.
# - The `rows` object contains data for each row in the table, with each cell having an identifier, label, and potentially metadata.
# - The `metadata` within columns and cells often includes detailed information such as geographic coordinates, scores, and match status.
#
# This detailed explanation should assist you in documenting the structure and data of your semantic enrichment process.

# %% [markdown]
# ### Example Breakdown
#
# #### Row Example ("r0")
#
# - **r0**: First row in the table.
#   - **Fecha_id**:
#     - **id**: `r0$Fecha_id`
#     - **label**: `2023-01-01`
#   - **Keyword**:
#     - **id**: `r0$Keyword`
#     - **label**: `alquiler pisos colindres`
#   - **Impresiones**:
#     - **id**: `r0$Impresiones`
#     - **label**: `1`
#   - **Clicks**:
#     - **id**: `r0$Clicks`
#     - **label**: `0`
#   - **City**:
#     - **id**: `r0$City`
#     - **label**: `Madrid`
#     - **metadata**: Array containing detailed metadata.
#       - **id**: `georss:40.41955,-3.69196`
#       - **name**: Object containing the name and URI.
#         - **value**: `Madrid, Community of Madrid, Spain`
#         - **uri**: `http://149.132.176.67:3002/map?polyline=40.41955,-3.69196`
#       - **feature**: Array of features.
#         - **id**: `all_labels`
#         - **value**: 100
#       - **score**: 1
#       - **match**: true
#       - **type**: Array of types.
#         - **id**: `wd:Q29934236`
#         - **name**: `GlobeCoordinate`
#     - **annotationMeta**:
#       - **annotated**: true
#       - **match**: Object containing match information.
#         - **value**: true
#         - **reason**: `reconciliator`
#       - **lowestScore**: 1
#       - **highestScore**: 1
#   - **County**:
#     - **id**: `r0$County`
#     - **label**: `Community of Madrid`
#   - **Country**:
#     - **id**: `r0$Country`
#     - **label**: `Spain`
#
# This should render correctly in markdown, ensuring the proper display of the data structure.

# %% [markdown]
# Sure! Let's focus on the `City` column and explore its metadata structure and details. The `City` column contains more detailed metadata due to its reconciliated status and geospatial information. Below is an explanation of the metadata structure for the `City` column:
#
# ### City Column Metadata Structure
#
# #### Columns Object (City Column)
# ```json
# "City": {
#     "id": "City",
#     "label": "City",
#     "status": "reconciliated",
#     "context": {
#         "georss": {
#             "uri": "http://www.google.com/maps/place/",
#             "total": 3,
#             "reconciliated": 3
#         }
#     },
#     "metadata": [
#         {
#             "id": "None:",
#             "match": true,
#             "score": 0,
#             "name": {
#                 "value": "",
#                 "uri": ""
#             },
#             "entity": [
#                 {
#                     "id": "wd:Q29934236",
#                     "name": {
#                         "value": "GlobeCoordinate",
#                         "uri": "http://149.132.176.67:3002/map?polyline=Q29934236"
#                     },
#                     "score": 0,
#                     "match": true,
#                     "type": []
#                 },
#                 {
#                     "id": "georss:point",
#                     "name": {
#                         "value": "point",
#                         "uri": "http://149.132.176.67:3002/map?polyline=point"
#                     },
#                     "score": 0,
#                     "match": true,
#                     "type": []
#                 }
#             ]
#         }
#     ],
#     "annotationMeta": {
#         "annotated": true,
#         "match": {
#             "value": true,
#             "reason": "reconciliator"
#         },
#         "lowestScore": 0,
#         "highestScore": 0
#     }
# }
# ```
#
# ### Explanation of the City Column Metadata
#
# 1. **City Column**
#    - **id**: "City" (Unique identifier for the column)
#    - **label**: "City" (Label or name of the column)
#    - **status**: "reconciliated" (Status indicating the column has been reconciliated)
#    - **context**: Additional context information specific to the City column.
#      - **georss**: Geographic RSS data containing:
#        - **uri**: Base URI for the geographic data (e.g., "http://www.google.com/maps/place/")
#        - **total**: Total number of reconciliated entries (e.g., 3)
#        - **reconciliated**: Number of entries reconciliated (e.g., 3)
#
# 2. **metadata**: Array containing detailed metadata objects for the column.
#    - **id**: "None:" (Identifier for the metadata entry)
#    - **match**: true (Boolean indicating if there is a match)
#    - **score**: 0 (Score for the match)
#    - **name**: Object with value and URI fields.
#      - **value**: "" (Name value, empty in this case)
#      - **uri**: "" (URI associated with the name, empty in this case)
#    - **entity**: Array of entity objects.
#      - **id**: "wd:Q29934236" (Identifier for the entity)
#      - **name**: Object containing the entity name and URI.
#        - **value**: "GlobeCoordinate" (Entity name)
#        - **uri**: "http://149.132.176.67:3002/map?polyline=Q29934236" (URI for the entity)
#      - **score**: 0 (Score for the entity)
#      - **match**: true (Boolean indicating if there is a match)
#      - **type**: [] (Array of types, empty in this case)
#      - **id**: "georss:point" (Another entity identifier)
#      - **name**: Object containing the entity name and URI.
#        - **value**: "point" (Entity name)
#        - **uri**: "http://149.132.176.67:3002/map?polyline=point" (URI for the entity)
#      - **score**: 0 (Score for the entity)
#      - **match**: true (Boolean indicating if there is a match)
#      - **type**: [] (Array of types, empty in this case)
#
# 3. **annotationMeta**: Metadata about the annotation for the column.
#    - **annotated**: true (Boolean indicating if the column is annotated)
#    - **match**: Object containing match information.
#      - **value**: true (Boolean indicating if there is a match)
#      - **reason**: "reconciliator" (Reason for the match)
#    - **lowestScore**: 0 (Lowest score for the annotation)
#    - **highestScore**: 0 (Highest score for the annotation)
#
# #### Example Row Data (City Cell)
# ```json
# "City": {
#     "id": "r0$City",
#     "label": "Madrid",
#     "metadata": [
#         {
#             "id": "georss:40.41955,-3.69196",
#             "name": {
#                 "value": "Madrid, Community of Madrid, Spain",
#                 "uri": "http://149.132.176.67:3002/map?polyline=40.41955,-3.69196"
#             },
#             "feature": [
#                 {
#                     "id": "all_labels",
#                     "value": 100
#                 }
#             ],
#             "score": 1,
#             "match": true,
#             "type": [
#                 {
#                     "id": "wd:Q29934236",
#                     "name": "GlobeCoordinate"
#                 },
#                 {
#                     "id": "georss:point",
#                     "name": "point"
#                 }
#             ]
#         }
#     ],
#     "annotationMeta": {
#         "annotated": true,
#         "match": {
#             "value": true,
#             "reason": "reconciliator"
#         },
#         "lowestScore": 1,
#         "highestScore": 1
#     }
# }
# ```
#
# ### Explanation of the City Cell Metadata
#
# 1. **City Cell**
#    - **id**: "r0$City" (Unique identifier for the cell)
#    - **label**: "Madrid" (Data value of the cell)
#
# 2. **metadata**: Array containing detailed metadata objects for the cell.
#    - **id**: "georss:40.41955,-3.69196" (Identifier for the metadata entry)
#    - **name**: Object with value and URI fields.
#      - **value**: "Madrid, Community of Madrid, Spain" (Name value)
#      - **uri**: "http://149.132.176.67:3002/map?polyline=40.41955,-3.69196" (URI associated with the name)
#    - **feature**: Array of feature objects.
#      - **id**: "all_labels" (Identifier for the feature)
#      - **value**: 100 (Value of the feature)
#    - **score**: 1 (Score for the match)
#    - **match**: true (Boolean indicating if there is a match)
#    - **type**: Array of types.
#      - **id**: "wd:Q29934236" (Identifier for the type)
#      - **name**: "GlobeCoordinate" (Name of the type)
#      - **id**: "georss:point" (Another type identifier)
#      - **name**: "point" (Name of the type)
#
# 3. **annotationMeta**: Metadata about the annotation for the cell.
#    - **annotated**: true (Boolean indicating if the cell is annotated)
#    - **match**: Object containing match information.
#      - **value**: true (Boolean indicating if there is a match)
#      - **reason**: "reconciliator" (Reason for the match)
#    - **lowestScore**: 1 (Lowest score for the annotation)
#    - **highestScore**: 1 (Highest score for the annotation)
#
# ### Summary
# - The `City` column and its cells contain detailed metadata related to geospatial information.
# - Metadata includes identifiers, names, URIs, feature details, scores, match statuses, and types.
# - The `annotationMeta` provides additional context about the annotation process, indicating whether the column or cell is annotated and providing scores and match reasons.
#
# This structure allows for enriched data representation with geographic coordinates and relevant metadata, facilitating more meaningful data analysis and integration.

# %% [markdown]
# ## **JSON File From Extension**

# %% [markdown]
# **Table Metadata**
# - **id**: `139`
# - **idDataset**: `30`
# - **name**: `JoT-Semtui-extended`
# - **nCols**: `10`
# - **nRows**: `3`
# - **nCells**: `30`
# - **nCellsReconciliated**: `3`
# - **lastModifiedDate**: `2024-06-06T11:00:51.530Z`
# - **minMetaScore**: `0`
# - **maxMetaScore**: `1`
#
# **Columns Metadata**
# - **Fecha_id**:
#   - **id**: `Fecha_id`
#   - **label**: `Fecha_id`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
# - **Keyword**:
#   - **id**: `Keyword`
#   - **label**: `Keyword`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
# - **Impresiones**:
#   - **id**: `Impresiones`
#   - **label**: `Impresiones`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
# - **Clicks**:
#   - **id**: `Clicks`
#   - **label**: `Clicks`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
# - **City**:
#   - **id**: `City`
#   - **label**: `City`
#   - **status**: `reconciliated`
#   - **context**:
#     - **georss**:
#       - **uri**: `http://www.google.com/maps/place/`
#       - **total**: `3`
#       - **reconciliated**: `3`
#   - **metadata**:
#     - **id**: `None:`
#       - **match**: `true`
#       - **score**: `0`
#       - **name**:
#         - **value**: ``
#         - **uri**: ``
#       - **entity**:
#         - **id**: `wd:Q29934236`
#           - **name**:
#             - **value**: `GlobeCoordinate`
#             - **uri**: `http://149.132.176.67:3002/map?polyline=Q29934236`
#           - **score**: `0`
#           - **match**: `true`
#           - **type**: `[]`
#         - **id**: `georss:point`
#           - **name**:
#             - **value**: `point`
#             - **uri**: `http://149.132.176.67:3002/map?polyline=point`
#           - **score**: `0`
#           - **match**: `true`
#           - **type**: `[]`
#   - **annotationMeta**:
#     - **annotated**: `true`
#     - **match**:
#       - **value**: `true`
#       - **reason**: `reconciliator`
#     - **lowestScore**: `0`
#     - **highestScore**: `0`
# - **County**:
#   - **id**: `County`
#   - **label**: `County`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
# - **Country**:
#   - **id**: `Country`
#   - **label**: `Country`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
# - **City_apparent_temperature_max**:
#   - **id**: `City_apparent_temperature_max`
#   - **label**: `City_apparent_temperature_max`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
# - **City_apparent_temperature_min**:
#   - **id**: `City_apparent_temperature_min`
#   - **label**: `City_apparent_temperature_min`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
# - **City_precipitation_sum**:
#   - **id**: `City_precipitation_sum`
#   - **label**: `City_precipitation_sum`
#   - **status**: `empty`
#   - **context**: `{}`
#   - **metadata**: `[]`
#
# **Rows Data**
#
# - **r0**:
#   - **Fecha_id**:
#     - **id**: `r0$Fecha_id`
#     - **label**: `2023-01-01`
#     - **metadata**: `[]`
#   - **Keyword**:
#     - **id**: `r0$Keyword`
#     - **label**: `alquiler pisos colindres`
#     - **metadata**: `[]`
#   - **Impresiones**:
#     - **id**: `r0$Impresiones`
#     - **label**: `1`
#     - **metadata**: `[]`
#   - **Clicks**:
#     - **id**: `r0$Clicks`
#     - **label**: `0`
#     - **metadata**: `[]`
#   - **City**:
#     - **id**: `r0$City`
#     - **label**: `Madrid`
#     - **metadata**:
#       - **id**: `georss:40.41955,-3.69196`
#         - **name**:
#           - **value**: `Madrid, Community of Madrid, Spain`
#           - **uri**: `http://149.132.176.67:3002/map?polyline=40.41955,-3.69196`
#         - **feature**:
#           - **id**: `all_labels`
#           - **value**: `100`
#         - **score**: `1`
#         - **match**: `true`
#         - **type**:
#           - **id**: `wd:Q29934236`
#             - **name**: `GlobeCoordinate`
#           - **id**: `georss:point`
#             - **name**: `point`
#     - **annotationMeta**:
#       - **annotated**: `true`
#       - **match**:
#         - **value**: `true`
#         - **reason**: `reconciliator`
#       - **lowestScore**: `1`
#       - **highestScore**: `1`
#   - **County**:
#     - **id**: `r0$County`
#     - **label**: `Community of Madrid`
#     - **metadata**: `[]`
#   - **Country**:
#     - **id**: `r0$Country`
#     - **label**: `Spain`
#     - **metadata**: `[]`
#   - **City_apparent_temperature_max**:
#     - **id**: `r0$City_apparent_temperature_max`
#     - **label**: `12,7`
#     - **metadata**: `[]`
#   - **City_apparent_temperature_min**:
#     - **id**: `r0$City_apparent_temperature_min`
#     - **label**: `0,8`
#     - **metadata**: `[]`
#   - **City_precipitation_sum**:
#     - **id**: `r0$City_precipitation_sum`
#     - **label**: `0`
#     - **metadata**: `[]`
#
# - **r1**:
#   - **Fecha_id**:
#     - **id**: `r1$Fecha_id`
#     - **label**: `2023-01-01`
#     - **metadata**: `[]`
#   - **Keyword**:
#     - **id**: `r1$Keyword`
#     - **label**: `alquiler pisos sestao`
#     - **metadata**: `[]`
#   - **Impresiones**:
#     - **id**: `r1$Impresiones`
#     - **label**: `1`
#     - **metadata**: `[]`
#   - **Clicks**:
#     - **id**: `r1$Clicks`
#     - **label**: `0`
#     - **metadata**: `[]`
#   - **City**:
#     - **id**: `r1$City`
#     - **label**: `Barcelona`
#     - **metadata**:
#       - **id**: `georss:41.38804,2.17001`
#         - **name**:
#           - **value**: `Barcelona, Catalonia, Spain`
#           - **uri**: `http://149.132.176.67:3002/map?polyline=41.38804,2.17001`
#         - **feature**:
#           - **id**: `all_labels`
#           - **value**: `100`
#         - **score**: `1`
#         - **match**: `true`
#         - **type**:
#           - **id**: `wd:Q29934236`
#             - **name**: `GlobeCoordinate`
#           - **id**: `georss:point`
#             - **name**: `point`
#     - **annotationMeta**:
#       - **annotated**: `true`
#       - **match**:
#         - **value**: `true`
#         - **reason**: `reconciliator`
#       - **lowestScore**: `1`
#       - **highestScore**: `1`
#   - **County**:
#     - **id**: `r1$County`
#     - **label**: `Catalonia`
#     - **metadata**: `[]`
#   - **Country**:
#     - **id**: `r1$Country`
#     - **label**: `Spain`
#     - **metadata**: `[]`
#   - **City_apparent_temperature_max**:
#     - **id**: `r1$City_apparent_temperature_max`
#     - **label**: `16,5`
#     - **metadata**: `[]`
#   - **City_apparent_temperature_min**:
#     - **id**: `r1$City_apparent_temperature_min`
#     - **label**: `4,2`
#     - **metadata**: `[]`
#   - **City_precipitation_sum**:
#     - **id**: `r1$City_precipitation_sum`
#     - **label**: `0`
#     - **metadata**: `[]`
#
# - **r2**:
#   - **Fecha_id**:
#     - **id**: `r2$Fecha_id`
#     - **label**: `2023-01-01`
#     - **metadata**: `[]`
#   - **Keyword**:
#     - **id**: `r2$Keyword`
#     - **label**: `steelcraft pedal car`
#     - **metadata**: `[]`
#   - **Impresiones**:
#     - **id**: `r2$Impresiones`
#     - **label**: `1`
#     - **metadata**: `[]`
#   - **Clicks**:
#     - **id**: `r2$Clicks`
#     - **label**: `0`
#     - **metadata**: `[]`
#   - **City**:
#     - **id**: `r2$City`
#     - **label**: `Buffalo`
#     - **metadata**:
#       - **id**: `georss:42.88545,-78.87846`
#         - **name**:
#           - **value**: `Buffalo, NY, United States`
#           - **uri**: `http://149.132.176.67:3002/map?polyline=42.88545,-78.87846`
#         - **feature**:
#           - **id**: `all_labels`
#           - **value**: `100`
#         - **score**: `1`
#         - **match**: `true`
#         - **type**:
#           - **id**: `wd:Q29934236`
#             - **name**: `GlobeCoordinate`
#           - **id**: `georss:point`
#             - **name**: `point`
#     - **annotationMeta**:
#       - **annotated**: `true`
#       - **match**:
#         - **value**: `true`
#         - **reason**: `reconciliator`
#       - **lowestScore**: `1`
#       - **highestScore**: `1`
#   - **County**:
#     - **id**: `r2$County`
#     - **label**: `New York`
#     - **metadata**: `[]`
#   - **Country**:
#     - **id**: `r2$Country`
#     - **label**: `United States`
#     - **metadata**: `[]`
#   - **City_apparent_temperature_max**:
#     - **id**: `r2$City_apparent_temperature_max`
#     - **label**: `2,6`
#     - **metadata**: `[]`
#   - **City_apparent_temperature_min**:
#     - **id**: `r2$City_apparent_temperature_min`
#     - **label**: `-2,8`
#     - **metadata**: `[]`
#   - **City_precipitation_sum**:
#     - **id**: `r2$City_precipitation_sum`
#     - **label**: `2,4`
#     - **metadata**: `[]`

# %% [markdown]
# Certainly! Let's compare the reconciliation JSON and the extended JSON, highlighting the new fields added in the extended JSON.
#
# ### Comparison
#
# #### Table Metadata
# **Reconciliation JSON:**
#
# **Table Metadata**
# - **id**: `140`
# - **idDataset**: `30`
# - **name**: `JoT-Semtui-reconciled`
# - **nCols**: `7`
# - **nRows**: `3`
# - **nCells**: `21`
# - **nCellsReconciliated**: `3`
# - **lastModifiedDate**: `2024-06-06T11:01:56.136Z`
# - **minMetaScore**: `0`
# - **maxMetaScore**: `1`
#
#
# **Extended JSON:**
#
# **Table Metadata**
# - **id**: `139`
# - **idDataset**: `30`
# - **name**: `JoT-Semtui-extended`
# - **nCols**: `10`
# - **nRows**: `3`
# - **nCells**: `30`
# - **nCellsReconciliated**: `3`
# - **lastModifiedDate**: `2024-06-06T11:00:51.530Z`
# - **minMetaScore**: `0`
# - **maxMetaScore**: `1`
#
#
# **Explanation:**
# - The extended JSON has 3 additional columns (`nCols`: 10 vs. 7).
# - The extended JSON has 9 more cells (`nCells`: 30 vs. 21).
# - The `id` and `lastModifiedDate` are different.
#
# #### Columns Metadata
# **Reconciliation JSON:**
#
# **Columns Metadata**
# - **Fecha_id**
# - **Keyword**
# - **Impresiones**
# - **Clicks**
# - **City**
# - **County**
# - **Country**
#
#
# **Extended JSON:**
#
# **Columns Metadata**
# - **Fecha_id**
# - **Keyword**
# - **Impresiones**
# - **Clicks**
# - **City**
# - **County**
# - **Country**
# - **City_apparent_temperature_max**
# - **City_apparent_temperature_min**
# - **City_precipitation_sum**
#
#
# **Explanation:**
# - Three new columns are added in the extended JSON:
#   - **City_apparent_temperature_max**: Holds the maximum apparent temperature data.
#   - **City_apparent_temperature_min**: Holds the minimum apparent temperature data.
#   - **City_precipitation_sum**: Holds the precipitation sum data.
#
# #### Rows Data
# **Reconciliation JSON:**
#
# - **r0**
#   - **Fecha_id**: `2023-01-01`
#   - **Keyword**: `alquiler pisos colindres`
#   - **Impresiones**: `1`
#   - **Clicks**: `0`
#   - **City**: `Madrid`
#   - **County**: `Community of Madrid`
#   - **Country**: `Spain`
#
#
# **Extended JSON:**
#
# - **r0**
#   - **Fecha_id**: `2023-01-01`
#   - **Keyword**: `alquiler pisos colindres`
#   - **Impresiones**: `1`
#   - **Clicks**: `0`
#   - **City**: `Madrid`
#   - **County**: `Community of Madrid`
#   - **Country**: `Spain`
#   - **City_apparent_temperature_max**: `12,7`
#   - **City_apparent_temperature_min**: `0,8`
#   - **City_precipitation_sum**: `0`
#
# **Explanation:**
# - Three new fields are added to each row in the extended JSON:
#   - **City_apparent_temperature_max**: Contains the maximum apparent temperature for the city.
#   - **City_apparent_temperature_min**: Contains the minimum apparent temperature for the city.
#   - **City_precipitation_sum**: Contains the precipitation sum for the city.
#
# ### Detailed Comparison of New Fields
#
# 1. **City_apparent_temperature_max**
#    - **Purpose**: To store the maximum apparent temperature recorded for the city.
#    - **Format**: Numeric values with a comma as a decimal separator (e.g., `12,7`).
#
# 2. **City_apparent_temperature_min**
#    - **Purpose**: To store the minimum apparent temperature recorded for the city.
#    - **Format**: Numeric values with a comma as a decimal separator (e.g., `0,8`).
#
# 3. **City_precipitation_sum**
#    - **Purpose**: To store the total precipitation recorded for the city.
#    - **Format**: Numeric values with a comma as a decimal separator (e.g., `0`).
#
# ### Conclusion
# The extended JSON includes additional weather-related data for each city, enhancing the dataset with temperature and precipitation information. These new fields provide a more comprehensive view of the environmental conditions associated with each city, allowing for more detailed analysis and insights.

# %% [markdown]
# Sure! Let's visualize the transformation of a row through three stages:
#
# 1. **Initial Stage (Zero Extra Fields)**
# 2. **Reconciliation Stage (Metadata Populated with Geographical Data)**
# 3. **Extension Stage (Weather Data Populated)**
#
# ### Initial Stage
# **JSON Snippet:**
# ```json
# {
#   "r0": {
#     "Fecha_id": {
#       "label": "2023-01-01"
#     },
#     "Keyword": {
#       "label": "alquiler pisos colindres"
#     },
#     "Impresiones": {
#       "label": "1"
#     },
#     "Clicks": {
#       "label": "0"
#     },
#     "City": {
#       "label": "Madrid"
#     },
#     "County": {
#       "label": "Community of Madrid"
#     },
#     "Country": {
#       "label": "Spain"
#     }
#   }
# }
# ```
#
# ### Reconciliation Stage
# **JSON Snippet:**
# ```json
# {
#   "r0": {
#     "Fecha_id": {
#       "label": "2023-01-01",
#       "metadata": []
#     },
#     "Keyword": {
#       "label": "alquiler pisos colindres",
#       "metadata": []
#     },
#     "Impresiones": {
#       "label": "1",
#       "metadata": []
#     },
#     "Clicks": {
#       "label": "0",
#       "metadata": []
#     },
#     "City": {
#       "label": "Madrid",
#       "metadata": [
#         {
#           "id": "georss:40.41955,-3.69196",
#           "name": {
#             "value": "Madrid, Community of Madrid, Spain",
#             "uri": "http://149.132.176.67:3002/map?polyline=40.41955,-3.69196"
#           },
#           "feature": [
#             {
#               "id": "all_labels",
#               "value": 100
#             }
#           ],
#           "score": 1,
#           "match": true,
#           "type": [
#             {
#               "id": "wd:Q29934236",
#               "name": "GlobeCoordinate"
#             },
#             {
#               "id": "georss:point",
#               "name": "point"
#             }
#           ]
#         }
#       ],
#       "annotationMeta": {
#         "annotated": true,
#         "match": {
#           "value": true,
#           "reason": "reconciliator"
#         },
#         "lowestScore": 1,
#         "highestScore": 1
#       }
#     },
#     "County": {
#       "label": "Community of Madrid",
#       "metadata": []
#     },
#     "Country": {
#       "label": "Spain",
#       "metadata": []
#     }
#   }
# }
# ```
#
# ### Extension Stage
# **JSON Snippet:**
# ```json
# {
#   "r0": {
#     "Fecha_id": {
#       "label": "2023-01-01",
#       "metadata": []
#     },
#     "Keyword": {
#       "label": "alquiler pisos colindres",
#       "metadata": []
#     },
#     "Impresiones": {
#       "label": "1",
#       "metadata": []
#     },
#     "Clicks": {
#       "label": "0",
#       "metadata": []
#     },
#     "City": {
#       "label": "Madrid",
#       "metadata": [
#         {
#           "id": "georss:40.41955,-3.69196",
#           "name": {
#             "value": "Madrid, Community of Madrid, Spain",
#             "uri": "http://149.132.176.67:3002/map?polyline=40.41955,-3.69196"
#           },
#           "feature": [
#             {
#               "id": "all_labels",
#               "value": 100
#             }
#           ],
#           "score": 1,
#           "match": true,
#           "type": [
#             {
#               "id": "wd:Q29934236",
#               "name": "GlobeCoordinate"
#             },
#             {
#               "id": "georss:point",
#               "name": "point"
#             }
#           ]
#         }
#       ],
#       "annotationMeta": {
#         "annotated": true,
#         "match": {
#           "value": true,
#           "reason": "reconciliator"
#         },
#         "lowestScore": 1,
#         "highestScore": 1
#       }
#     },
#     "County": {
#       "label": "Community of Madrid",
#       "metadata": []
#     },
#     "Country": {
#       "label": "Spain",
#       "metadata": []
#     },
#     "City_apparent_temperature_max": {
#       "label": "12,7",
#       "metadata": []
#     },
#     "City_apparent_temperature_min": {
#       "label": "0,8",
#       "metadata": []
#     },
#     "City_precipitation_sum": {
#       "label": "0",
#       "metadata": []
#     }
#   }
# }
# ```
#
# ### Explanation of New Fields
#
# 1. **Reconciliation Stage:**
#    - **Metadata for City:**
#      - **id**: `georss:40.41955,-3.69196`
#      - **name**: Object with value `Madrid, Community of Madrid, Spain` and uri.
#      - **feature**: Array of features, e.g., `all_labels` with value `100`.
#      - **score**: `1`
#      - **match**: `true`
#      - **type**: Array with `GlobeCoordinate` and `point`.
#    - **annotationMeta for City:**
#      - **annotated**: `true`
#      - **match**: Object with value `true` and reason `reconciliator`.
#      - **lowestScore**: `1`
#      - **highestScore**: `1`
#
# 2. **Extension Stage:**
#    - **New Columns Added:**
#      - **City_apparent_temperature_max**: `12,7`
#      - **City_apparent_temperature_min**: `0,8`
#      - **City_precipitation_sum**: `0`
#
#
#
# ### Summary
# This visualization and comparison show how a row transforms from having basic fields to having enriched geographical metadata and then further extends to include weather data obtained from OpenMeteo. Each stage builds on the previous one by adding more detailed and relevant information.

# %% [markdown]
# Certainly! As a senior software engineer, I'll refactor and optimize the code, focusing on readability, maintainability, and efficiency. Here's an improved version of the code:
#
# ```python
# from typing import Dict, List, Any
# from dataclasses import dataclass, field
#
# @dataclass
# class ColumnMetadata:
#     id: str = 'None:'
#     match: bool = True
#     score: int = 0
#     name: Dict[str, str] = field(default_factory=lambda: {'value': '', 'uri': ''})
#     entity: List[Dict[str, Any]] = field(default_factory=list)
#
# @dataclass
# class RowMetadata:
#     id: str = ''
#     name: Dict[str, str] = field(default_factory=lambda: {'value': '', 'uri': ''})
#     feature: List[Dict[str, Any]] = field(default_factory=lambda: [{'id': 'all_labels', 'value': 100}])
#     score: int = 1
#     match: bool = True
#     type: List[Dict[str, str]] = field(default_factory=list)
#
# @dataclass
# class AnnotationMeta:
#     annotated: bool = True
#     match: Dict[str, Any] = field(default_factory=lambda: {'value': True, 'reason': 'reconciliator'})
#     lowestScore: int = 0
#     highestScore: int = 0
#
# def update_metadata(input_metadata: List[Dict[str, Any]], MetadataClass) -> List[Dict[str, Any]]:
#     if not input_metadata:
#         return []
#
#     metadata = MetadataClass(**input_metadata[0])
#     return [metadata.__dict__]
#
# def create_column(col: Dict[str, Any], is_reconciliated: bool, is_weather: bool = False) -> Dict[str, Any]:
#     column = {
#         'id': col['id'],
#         'label': col['label'],
#         'status': 'reconciliated' if is_reconciliated else col.get('status', 'empty'),
#         'context': col.get('context', {}),
#         'metadata': col.get('metadata', [])
#     }
#
#     if is_reconciliated:
#         column['metadata'] = update_metadata(col['metadata'], ColumnMetadata)
#         column['annotationMeta'] = AnnotationMeta().__dict__
#
#     if is_weather:
#         column['metadata'] = []
#         column['status'] = 'empty'
#
#     return column
#
# def create_cell(cell: Dict[str, Any], is_reconciliated: bool, is_weather: bool = False) -> Dict[str, Any]:
#     new_cell = {
#         'id': cell['id'],
#         'label': cell['label'],
#         'metadata': cell.get('metadata', [])
#     }
#
#     if is_reconciliated:
#         new_cell['metadata'] = update_metadata(cell['metadata'], RowMetadata)
#         new_cell['annotationMeta'] = AnnotationMeta(lowestScore=1, highestScore=1).__dict__
#
#     if is_weather:
#         new_cell['metadata'] = []
#
#     return new_cell
#
# def merge_reconciled_and_extension(reconciled_json: Dict[str, Any], extension_json: Dict[str, Any],
#                                    reconciliated_column_name: str, properties: List[str]) -> Dict[str, Any]:
#     merged_json = {
#         'table': extension_json['table'],
#         'columns': {},
#         'rows': {},
#         'id': extension_json['id']
#     }
#
#     # Process columns
#     for col_id, col in reconciled_json['columns'].items():
#         is_reconciliated = col_id == reconciliated_column_name
#         merged_json['columns'][col_id] = create_column(col, is_reconciliated)
#
#     # Add weather columns
#     for prop in properties:
#         col_id = f"{reconciliated_column_name}_{prop}"
#         merged_json['columns'][col_id] = create_column({'id': col_id, 'label': col_id}, False, True)
#
#     # Process rows
#     for row_id, row in reconciled_json['rows'].items():
#         merged_json['rows'][row_id] = {'id': row['id'], 'cells': {}}
#         for cell_id, cell in row['cells'].items():
#             is_reconciliated = cell_id == reconciliated_column_name
#             merged_json['rows'][row_id]['cells'][cell_id] = create_cell(cell, is_reconciliated)
#
#         # Add weather data
#         for prop in properties:
#             cell_id = f"{reconciliated_column_name}_{prop}"
#             weather_cell = {
#                 'id': f"{row_id}${cell_id}",
#                 'label': extension_json['rows'][row_id]['cells'][prop]['label'],
#             }
#             merged_json['rows'][row_id]['cells'][cell_id] = create_cell(weather_cell, False, True)
#
#     return merged_json
#
# def format_json_for_backend(merged_json: Dict[str, Any]) -> Dict[str, Any]:
#     return {
#         "table": {
#             "id": merged_json["table"]["id"],
#             "idDataset": merged_json["table"]["idDataset"],
#             "name": merged_json["table"]["name"],
#             "nCols": merged_json["table"]["nCols"],
#             "nRows": merged_json["table"]["nRows"],
#             "nCells": merged_json["table"]["nCells"],
#             "nCellsReconciliated": merged_json["table"]["nCellsReconciliated"],
#             "lastModifiedDate": merged_json["table"]["lastModifiedDate"],
#             "minMetaScore": merged_json["table"].get("minMetaScore", 0),
#             "maxMetaScore": merged_json["table"].get("maxMetaScore", 0)
#         },
#         'columns': merged_json['columns'],
#         'rows': merged_json['rows'],
#         'id': merged_json['id']
#     }
#
# def process_and_format_json(reconciled_json: Dict[str, Any], extension_json: Dict[str, Any],
#                             reconciliated_column_name: str, properties: List[str]) -> Dict[str, Any]:
#     merged_json = merge_reconciled_and_extension(reconciled_json, extension_json, reconciliated_column_name, properties)
#     return format_json_for_backend(merged_json)
#
# # Example usage
# reconciliated_column_name = 'City'
# properties = ['apparent_temperature_max', 'apparent_temperature_min', 'precipitation_sum']
#
# result = process_and_format_json(reconciled_json, extension_json, reconciliated_column_name, properties)
# ```
#
# Key improvements and optimizations:
#
# 1. **Type Hints**: Added type hints to improve code readability and catch potential type-related errors early.
#
# 2. **Dataclasses**: Used dataclasses for `ColumnMetadata`, `RowMetadata`, and `AnnotationMeta` to create more structured and self-documenting code.
#
# 3. **Modular Functions**: Created separate functions `create_column` and `create_cell` to handle the creation of columns and cells, reducing code duplication and improving maintainability.
#
# 4. **Generic Metadata Update**: The `update_metadata` function now works with both column and row metadata, reducing code duplication.
#
# 5. **Simplified Logic**: Removed nested if statements where possible and used more concise expressions.
#
# 6. **Consistent Naming**: Used more consistent and descriptive variable names throughout the code.
#
# 7. **Default Values**: Utilized default values in dataclasses to handle missing data more gracefully.
#
# 8. **Reduced Repetition**: Consolidated repeated code patterns into reusable functions.
#
# 9. **Improved Readability**: Broke down complex operations into smaller, more manageable pieces.
#
# This refactored version maintains the same functionality as the original code but is more modular, easier to read, and easier to maintain. It also provides better type safety and is more resistant to potential errors from unexpected input data structures.
